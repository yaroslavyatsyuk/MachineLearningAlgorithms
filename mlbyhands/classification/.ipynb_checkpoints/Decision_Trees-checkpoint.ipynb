# %% [markdown]
# # Decision Tree Classifier

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
class DecisionTreeClassifier:
    
    def __init__(self, max_depth = 6, min_samples_split=2, min_impurity_decrease=0.0):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.min_impurity_decrease = min_impurity_decrease
        self.feature_importance = {}
        self.nodes = []
        
    def fit(self, data, features, target):
        self.n = len(data)
        self.features = features
        self.tree = self.__train_tree(data, features, target, max_depth=self.max_depth, 
                                      min_samples_split=self.min_samples_split, min_impurity_decrease=self.min_impurity_decrease)
        
    def predict(self, X):
        predictions = X.apply(lambda x: self.__predict(self.tree, x), axis=1)
        return np.array([pred[0] for pred in predictions])
    
    def predict_proba(self, X):
        predictions = X.apply(lambda x: self.__predict(self.tree, x), axis=1)
        return np.array([pred[1] for pred in predictions])
    
    def get_feature_importances(self):
        importance_data = dict.fromkeys(self.features, 0.0)
        first_node = custom_decision_tree.nodes[0]
        
        for node in self.nodes:
            left = node["left"]
            right = node["right"]

            importance_data[node["splitting_feature"]] += (
                node["weighted_n_node_samples"] * node["impurity"] -
                left["weighted_n_node_samples"] * left["impurity"] -
                right["weighted_n_node_samples"] * right["impurity"]
            )

        importance_data_values = np.array(list(importance_data.values())) / first_node["weighted_n_node_samples"]
        norms = importance_data_values.sum()
        importance_data_values /= norms
        
        for i, key in enumerate(importance_data):
            importance_data[key] = importance_data_values[i]
    
        return sorted(importance_data.items(), key=lambda x: x[1], reverse=True)
   
    def __predict(self, tree, x):   
        if tree['is_leaf']:
            return (tree['prediction'], tree["probability"])
        else:
            split_feature_value = x[tree['splitting_feature']]
            threshold =  tree["split_threshold"]
            if(threshold != None):
                if split_feature_value < threshold:
                    return self.__predict(tree['left'], x)
                else:
                    return self.__predict(tree['right'], x)
            else:
                if split_feature_value == 0:
                    return self.__predict(tree['left'], x)
                else:
                    return self.__predict(tree['right'], x)
    
    def ___reached_minimum_node_size(self, data, min_node_size):
        return len(data) <= min_node_size  
    
    def __intermediate_node_num_mistakes(self, labels_in_node):
        if len(labels_in_node) == 0:
            return 0

        num_of_first_class = (labels_in_node == 1).sum()
        num_of_second_class = (labels_in_node == 0).sum()
        
        return num_of_second_class if num_of_first_class > num_of_second_class else num_of_first_class

    def __create_node(self, splitting_feature, split_threshold, left_tree, right_tree, weighted_n_node_samples, impurity):
        return {"is_leaf"                 : False, 
                "prediction"              : None,
                "probability"             : None,
                "splitting_feature"       : splitting_feature,
                "split_threshold"         : split_threshold,
                "weighted_n_node_samples" : weighted_n_node_samples,
                "impurity"                : impurity,
                "left"                    : left_tree, 
                "right"                   : right_tree}
    
    def __calculate_gini(self, labels_in_node):
        if len(labels_in_node) == 0:
            return 0
        
        n = len(labels_in_node)
        
        num_of_first_class = (labels_in_node == 1).sum()
        num_of_second_class = (labels_in_node == 0).sum()
        
        majority_class = num_of_first_class if num_of_first_class > num_of_second_class else num_of_second_class
        
        p = majority_class / n
        
        gini = 2*p*(1 - p)
        return gini
    
    def __is_continuous_variable(self, feature_column):
        unique_values = feature_column.unique()
        if(len(unique_values) == 2 and (1 in unique_values and 0 in unique_values)):
            return False
        else:
            return True     
        
    def __create_leaf(self, target_values, weighted_n_node_samples, node_impurity):
        # Create a leaf node
        leaf = {'splitting_feature' : None,
                "weighted_n_node_samples": weighted_n_node_samples,
                "impurity": node_impurity,
                'left' : None,
                'right' : None,
                'is_leaf': True   }

        num_ones = len(target_values[target_values == 1])
        num_zeros = len(target_values[target_values == 0])
        
        if(len(target_values) > 0):
            leaf["probability"] = num_ones/(len(target_values))
        else: 
            leaf["probability"] = 0
        
        # For the leaf node, set the prediction to be the majority class.
        if num_ones > num_zeros:
            leaf['prediction'] = 1            
        else:
            leaf['prediction'] = 0
           

        return leaf     
        
    def __train_tree(self, data, features, target, current_depth = 0, max_depth = 6,
                     min_samples_split=10, min_impurity_decrease=-1):
    
        remaining_features = features[:]

        target_values = data[target]
        weighted_n_node_samples = len(data)/self.n
        node_impurity = self.__calculate_gini(target_values)
        
        print("--------------------------------------------------------------------")
        print("Subtree, depth = %s (%s data points)." % (current_depth, len(target_values)))

        # Stopping condition 1: All nodes are of the same type.
        if self.__intermediate_node_num_mistakes(target_values) == 0:
            print("Stopping condition 1 reached. All data points have the same target value.")
            return self.__create_leaf(target_values, weighted_n_node_samples, node_impurity)

        # Stopping condition 2: No more features to split on.
        if remaining_features == []:
            print("Stopping condition 2 reached. No remaining features.")
            return self.__create_leaf(target_values, weighted_n_node_samples, node_impurity)

        # Early stopping condition 1: Reached max depth limit.
        if current_depth >= max_depth:
            print("Early stopping condition 1 reached. Reached maximum depth.")
            return self.__create_leaf(target_values, weighted_n_node_samples, node_impurity)

        # Early stopping condition 2: Reached the minimum node size.
        if len(data) <= min_samples_split:  
            print("Early stopping condition 2 reached. Reached minimum node size.")
            return self.__create_leaf(target_values, weighted_n_node_samples, node_impurity)
        
        # Find the best splitting feature
        splitting_feature, feature_impurity, split_threshold = self.__find_best_splitting_feature(data, features, target)
        
        # descrite variable case 
        if split_threshold == None:
            left_split = data[data[splitting_feature] == 0]
            right_split = data[data[splitting_feature] == 1]
        # continuoue variable case
        else:
            left_split = data[data[splitting_feature] < split_threshold]
            right_split = data[data[splitting_feature] >= split_threshold]

        # Early stopping condition 3: Minimum impurity decrease
        impurity_after_split = feature_impurity
            
        if (node_impurity - impurity_after_split) <= min_impurity_decrease:
            print("Early stopping condition 3 reached. Minimum error reduction.")
            return self.__create_leaf(target_values, weighted_n_node_samples, node_impurity)

        remaining_features.remove(splitting_feature)
        print("Split on feature %s. (%s, %s)" % (\
                          splitting_feature, len(left_split), len(right_split)))

        # Recurse on left and right subtrees
        left_tree = self.__train_tree(left_split, remaining_features, target, 
                                         current_depth + 1, max_depth, min_samples_split, min_impurity_decrease)        

        right_tree = self.__train_tree(right_split, remaining_features, target, 
                                         current_depth + 1, max_depth, min_samples_split, min_impurity_decrease)


        node = self.__create_node(splitting_feature, split_threshold, left_tree, right_tree, weighted_n_node_samples, node_impurity)
        self.nodes.append(node)
        return node
    
    
    def __find_best_splitting_feature(self, data, features, target):
        best_feature = None 
        best_feature_val_for_split = None
        best_gini = 10     
        
        num_data_points = float(len(data))  
        
        # Loop through each feature to consider splitting on that feature
        for feature in features:
            curent_feature_gini = None
            is_continuous = False
            best_feature_val = None
            
            # handle continuous feature
            if self.__is_continuous_variable(data[feature]):
                unique_inputs = data[feature].unique()
                best_gini_for_feature = 10
                for val in unique_inputs:
                    left_split = data[data[feature] < val]
                    right_split = data[data[feature] >= val]
                    
                    gini_left_split = self.__calculate_gini(left_split[target])
                    gini_right_split = self.__calculate_gini(right_split[target])
                    
                    gini_for_curent_val = (len(left_split) / num_data_points) * gini_left_split + (len(right_split) / num_data_points) * gini_right_split
                    if(gini_for_curent_val < best_gini_for_feature):
                        best_feature_val = val
                        best_gini_for_feature = gini_for_curent_val
                
                curent_feature_gini = best_gini_for_feature
                is_continuous = True
            
            # handle discrete feature     
            else:
                left_split = data[data[feature] == 0]
                right_split = data[data[feature] == 1]

                gini_left_split = self.__calculate_gini(left_split[target])
                gini_right_split = self.__calculate_gini(right_split[target])
                
                curent_feature_gini = (len(left_split) / num_data_points) * gini_left_split + (len(right_split) / num_data_points) * gini_right_split
            
            
            if curent_feature_gini < best_gini:
                best_feature = feature
                best_gini = curent_feature_gini
                if is_continuous:
                    best_feature_val_for_split = best_feature_val
                else:
                    best_feature_val_for_split = None

        return [best_feature, best_gini, best_feature_val_for_split]

# %% [markdown]
# ## Load already prepared data to test implementation

# %%
train = pd.read_csv("./data/loans_data_train.csv", index_col=0)
valid = pd.read_csv("./data/loans_data_validation.csv", index_col=0)

# %%
train["safe_loans"] = train["safe_loans"].apply(lambda x: 1 if x == 1 else 0)
valid["safe_loans"] = valid["safe_loans"].apply(lambda x: 1 if x == 1 else 0)

# %%
target = "safe_loans"
features = list(train.columns)
features.remove("safe_loans") 
features
# Out:
# ['grade.A',
#  'grade.B',
#  'grade.C',
#  'grade.D',
#  'grade.E',
#  'grade.F',
#  'grade.G',
#  'term. 36 months',
#  'term. 60 months',
#  'home_ownership.MORTGAGE',
#  'home_ownership.OTHER',
#  'home_ownership.OWN',
#  'home_ownership.RENT',
#  'emp_length.1 year',
#  'emp_length.10+ years',
#  'emp_length.2 years',
#  'emp_length.3 years',
#  'emp_length.4 years',
#  'emp_length.5 years',
#  'emp_length.6 years',
#  'emp_length.7 years',
#  'emp_length.8 years',
#  'emp_length.9 years',
#  'emp_length.< 1 year',
#  'emp_length.n/a']

# %% [markdown]
# ## BUILD CUSTOM DECISION TREE AND COMPARE WITH SKLEARN

# %%
custom_decision_tree = DecisionTreeClassifier(max_depth = 6, min_impurity_decrease=-1)
custom_decision_tree.fit(train, features, target)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 1 (32094 data points).
# Split on feature grade.B. (21728, 10366)
# --------------------------------------------------------------------
# Subtree, depth = 2 (21728 data points).
# Split on feature grade.C. (12316, 9412)
# --------------------------------------------------------------------
# Subtree, depth = 3 (12316 data points).
# Split on feature term. 36 months. (5884, 6432)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade.D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature home_ownership.RENT. (2203, 1623)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2203 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (1623 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2058 data points).
# Split on feature home_ownership.MORTGAGE. (923, 1135)
# --------------------------------------------------------------------
# Subtree, depth = 6 (923 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (1135 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (6432 data points).
# Split on feature home_ownership.MORTGAGE. (4192, 2240)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4192 data points).
# Split on feature emp_length.n/a. (3988, 204)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3988 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (204 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2240 data points).
# Split on feature grade.D. (586, 1654)
# --------------------------------------------------------------------
# Subtree, depth = 6 (586 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (1654 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 3 (9412 data points).
# Split on feature emp_length.n/a. (9044, 368)
# --------------------------------------------------------------------
# Subtree, depth = 4 (9044 data points).
# Split on feature term. 36 months. (2139, 6905)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2139 data points).
# Split on feature home_ownership.RENT. (1501, 638)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1501 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (638 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (6905 data points).
# Split on feature home_ownership.MORTGAGE. (4113, 2792)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4113 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2792 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (368 data points).
# Split on feature term. 36 months. (51, 317)
# --------------------------------------------------------------------
# Subtree, depth = 5 (51 data points).
# Split on feature home_ownership.OWN. (42, 9)
# --------------------------------------------------------------------
# Subtree, depth = 6 (42 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (9 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (317 data points).
# Split on feature home_ownership.OTHER. (316, 1)
# --------------------------------------------------------------------
# Subtree, depth = 6 (316 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (1 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 (10366 data points).
# Split on feature term. 36 months. (1048, 9318)
# --------------------------------------------------------------------
# Subtree, depth = 3 (1048 data points).
# Split on feature emp_length.5 years. (969, 79)
# --------------------------------------------------------------------
# Subtree, depth = 4 (969 data points).
# Split on feature home_ownership.MORTGAGE. (367, 602)
# --------------------------------------------------------------------
# Subtree, depth = 5 (367 data points).
# Split on feature emp_length.10+ years. (294, 73)
# --------------------------------------------------------------------
# Subtree, depth = 6 (294 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (73 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (602 data points).
# Split on feature emp_length.9 years. (580, 22)
# --------------------------------------------------------------------
# Subtree, depth = 6 (580 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (79 data points).
# Split on feature home_ownership.MORTGAGE. (34, 45)
# --------------------------------------------------------------------
# Subtree, depth = 5 (34 data points).
# Split on feature home_ownership.OWN. (25, 9)
# --------------------------------------------------------------------
# Subtree, depth = 6 (25 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (9 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (45 data points).
# Split on feature grade.C. (0, 45)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (45 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 3 (9318 data points).
# Split on feature emp_length.n/a. (8934, 384)
# --------------------------------------------------------------------
# Subtree, depth = 4 (8934 data points).
# Split on feature home_ownership.RENT. (4845, 4089)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4845 data points).
# Split on feature home_ownership.OTHER. (4828, 17)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4828 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (17 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (4089 data points).
# Split on feature emp_length.2 years. (3593, 496)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3593 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (496 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (384 data points).
# Split on feature home_ownership.MORTGAGE. (210, 174)
# --------------------------------------------------------------------
# Subtree, depth = 5 (210 data points).
# Split on feature home_ownership.OWN. (148, 62)
# --------------------------------------------------------------------
# Subtree, depth = 6 (148 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (62 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (174 data points).
# Split on feature grade.C. (0, 174)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (174 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 1 (5130 data points).
# Split on feature home_ownership.RENT. (3280, 1850)
# --------------------------------------------------------------------
# Subtree, depth = 2 (3280 data points).
# Split on feature emp_length.n/a. (3117, 163)
# --------------------------------------------------------------------
# Subtree, depth = 3 (3117 data points).
# Split on feature term. 36 months. (71, 3046)
# --------------------------------------------------------------------
# Subtree, depth = 4 (71 data points).
# Split on feature emp_length.8 years. (67, 4)
# --------------------------------------------------------------------
# Subtree, depth = 5 (67 data points).
# Split on feature emp_length.7 years. (64, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (64 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 (4 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 (3046 data points).
# Split on feature emp_length.4 years. (2833, 213)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2833 data points).
# Split on feature home_ownership.OWN. (2458, 375)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2458 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (375 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (213 data points).
# Split on feature home_ownership.OWN. (187, 26)
# --------------------------------------------------------------------
# Subtree, depth = 6 (187 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (26 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 3 (163 data points).
# Split on feature home_ownership.MORTGAGE. (49, 114)
# --------------------------------------------------------------------
# Subtree, depth = 4 (49 data points).
# Split on feature term. 36 months. (1, 48)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 (48 data points).
# Split on feature grade.B. (0, 48)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (48 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (114 data points).
# Split on feature term. 36 months. (3, 111)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade.B. (0, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (111 data points).
# Split on feature grade.B. (0, 111)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (111 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 (1850 data points).
# Split on feature term. 36 months. (26, 1824)
# --------------------------------------------------------------------
# Subtree, depth = 3 (26 data points).
# Split on feature emp_length.3 years. (24, 2)
# --------------------------------------------------------------------
# Subtree, depth = 4 (24 data points).
# Split on feature emp_length.10+ years. (20, 4)
# --------------------------------------------------------------------
# Subtree, depth = 5 (20 data points).
# Split on feature emp_length.n/a. (19, 1)
# --------------------------------------------------------------------
# Subtree, depth = 6 (19 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (1 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 (4 data points).
# Split on feature grade.B. (0, 4)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (4 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1824 data points).
# Split on feature emp_length.7 years. (1759, 65)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1759 data points).
# Split on feature emp_length.n/a. (1688, 71)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1688 data points).
# Split on feature emp_length.10+ years. (1407, 281)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1407 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 (281 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 (71 data points).
# Split on feature grade.B. (0, 71)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (71 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 (65 data points).
# Split on feature grade.B. (0, 65)
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 (65 data points).
# Split on feature grade.C. (0, 65)
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 (65 data points).
# Early stopping condition 1 reached. Reached maximum depth.

# %%
def accuracy(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    return (y_true == y_pred).sum() / len(y_true)

# %%
y_pred_custom = custom_decision_tree.predict(valid[features])
y_true = valid[target]

accuracy(y_true, y_pred_custom)
# Out:
# 0.6223610512710038

# %%
dtree = sklearn.tree.DecisionTreeClassifier()
sklearn_tree = dtree.fit(X=train[features], y=train[target])

# %%
y_pred_sklearn = sklearn_tree.predict(valid[features])

# %%
accuracy(y_true, y_pred_sklearn)
# Out:
# 0.6198836708315382

# %%
custom_decision_tree.predict_proba(valid[features])
# Out:
# array([0.30877573, 0.7921074 , 0.23906346, ..., 0.37963892, 0.37963892,
#        0.        ])

# %%
custom_decision_tree.predict(valid[features])
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_true, custom_decision_tree.predict_proba(valid[features]))
# Out:
# 0.6670857710118373

# %%
roc_auc_score(y_true, sklearn_tree.predict_proba(valid[features])[:,1])
# Out:
# 0.6642619855813812

# %%
cardio_df = pd.read_csv("./data/cardio_train.csv", sep=";")

# %%
cardio_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# Drop id

cardio_df = cardio_df.drop(columns = 'id')

# %%
# since the age is given in days, we convert it into years

cardio_df['age'] = cardio_df['age']/365

# %%
cardio_df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  50.391781       2     168    62.0    110     80            1     1      0
# 1  55.419178       1     156    85.0    140     90            3     1      0
# 2  51.663014       1     165    64.0    130     70            3     1      0
# 3  48.282192       2     169    82.0    150    100            1     1      0
# 4  47.873973       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# checking the null values
cardio_df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Checking the dataframe information

cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 6.4 MB

# %%
cardio_df["age"] = cardio_df["age"].astype(int)

# %%
# split the dataframe into target and features
features = list(cardio_df.columns)
features.remove("cardio")
target = "cardio"

# %%
custom_decision_tree_c = DecisionTreeClassifier(max_depth = 6, min_impurity_decrease=0.0, min_samples_split=100)
custom_decision_tree_c.fit(cardio_df, features, target)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (70000 data points).
# ap_hi 130
# Split on feature ap_hi. (41326, 28674)
# --------------------------------------------------------------------
# Subtree, depth = 1 (41326 data points).
# age 55
# Split on feature age. (25621, 15705)
# --------------------------------------------------------------------
# Subtree, depth = 2 (25621 data points).
# cholesterol 3
# Split on feature cholesterol. (24523, 1098)
# --------------------------------------------------------------------
# Subtree, depth = 3 (24523 data points).
# ap_lo 78
# Split on feature ap_lo. (8286, 16237)
# --------------------------------------------------------------------
# Subtree, depth = 4 (8286 data points).
# weight 65.0
# Split on feature weight. (3393, 4893)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3393 data points).
# gluc 2
# Split on feature gluc. (3175, 218)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3175 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 4        0
# 32       0
# 40       0
# 60       0
# 80       0
#         ..
# 69922    0
# 69935    0
# 69937    0
# 69951    0
# 69961    0
# Name: cardio, Length: 3175, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (218 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 17       0
# 107      1
# 536      0
# 982      0
# 1011     1
#         ..
# 68009    0
# 68759    0
# 69400    0
# 69520    0
# 69919    0
# Name: cardio, Length: 218, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (4893 data points).
# gluc 2
# Split on feature gluc. (4404, 489)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4404 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 8        0
# 9        0
# 13       0
# 18       0
# 49       0
#         ..
# 69901    1
# 69932    0
# 69953    1
# 69978    1
# 69990    1
# Name: cardio, Length: 4404, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (489 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 56       0
# 113      1
# 316      0
# 509      0
# 561      0
#         ..
# 69545    1
# 69586    0
# 69673    1
# 69793    0
# 69808    1
# Name: cardio, Length: 489, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (16237 data points).
# weight 80.0
# Split on feature weight. (12377, 3860)
# --------------------------------------------------------------------
# Subtree, depth = 5 (12377 data points).
# active None
# Split on feature active. (2433, 9944)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2433 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 12       0
# 47       0
# 149      0
# 167      0
# 201      0
#         ..
# 69847    0
# 69859    0
# 69881    0
# 69965    0
# 69980    0
# Name: cardio, Length: 2433, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (9944 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 0        0
# 11       0
# 27       0
# 28       0
# 41       1
#         ..
# 69977    0
# 69983    0
# 69986    0
# 69987    0
# 69995    0
# Name: cardio, Length: 9944, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (3860 data points).
# active None
# Split on feature active. (791, 3069)
# --------------------------------------------------------------------
# Subtree, depth = 6 (791 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 15       1
# 89       0
# 116      0
# 144      1
# 195      0
#         ..
# 69591    0
# 69609    1
# 69612    1
# 69738    0
# 69764    0
# Name: cardio, Length: 791, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (3069 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 20       0
# 36       0
# 103      0
# 117      1
# 179      1
#         ..
# 69924    0
# 69927    1
# 69941    0
# 69957    0
# 69984    1
# Name: cardio, Length: 3069, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 3 (1098 data points).
# gluc 3
# Split on feature gluc. (467, 631)
# --------------------------------------------------------------------
# Subtree, depth = 4 (467 data points).
# ap_lo 79
# Split on feature ap_lo. (121, 346)
# --------------------------------------------------------------------
# Subtree, depth = 5 (121 data points).
# weight 52.0
# Split on feature weight. (7, 114)
# --------------------------------------------------------------------
# Subtree, depth = 6 (7 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 1039     0
# 6948     0
# 11734    1
# 17709    0
# 39846    0
# 48245    0
# 49929    1
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (114 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 1983     0
# 3231     1
# 3344     1
# 4116     1
# 4204     1
#         ..
# 64265    0
# 64823    1
# 67085    0
# 67305    1
# 67692    1
# Name: cardio, Length: 114, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (346 data points).
# height 158
# Split on feature height. (71, 275)
# --------------------------------------------------------------------
# Subtree, depth = 6 (71 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 30       1
# 709      1
# 1278     1
# 1496     1
# 1531     1
#         ..
# 64728    1
# 65628    1
# 65728    1
# 68228    1
# 69566    1
# Name: cardio, Length: 71, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (275 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 172      1
# 231      1
# 747      0
# 963      1
# 1436     0
#         ..
# 68569    0
# 68782    1
# 69371    1
# 69530    1
# 69913    0
# Name: cardio, Length: 275, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (631 data points).
# weight 81.0
# Split on feature weight. (506, 125)
# --------------------------------------------------------------------
# Subtree, depth = 5 (506 data points).
# ap_lo 79
# Split on feature ap_lo. (118, 388)
# --------------------------------------------------------------------
# Subtree, depth = 6 (118 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 2462     0
# 2519     0
# 3009     0
# 5574     0
# 6158     0
#         ..
# 65765    0
# 66771    0
# 67597    0
# 67850    0
# 68241    0
# Name: cardio, Length: 118, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (388 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 431      0
# 504      0
# 812      0
# 900      1
# 949      1
#         ..
# 68723    1
# 68784    0
# 69001    0
# 69240    0
# 69836    1
# Name: cardio, Length: 388, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (125 data points).
# height 172
# Split on feature height. (91, 34)
# --------------------------------------------------------------------
# Subtree, depth = 6 (91 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 150      1
# 1865     1
# 2925     1
# 2934     0
# 2954     1
#         ..
# 63785    1
# 63833    1
# 63890    0
# 66657    1
# 67157    1
# Name: cardio, Length: 91, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (34 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 568      0
# 3647     0
# 8857     1
# 9363     0
# 11601    1
# 12100    1
# 14031    1
# 14747    0
# 17193    1
# 17546    0
# 17950    0
# 17959    0
# 18412    1
# 20415    1
# 21344    0
# 28435    0
# 29676    0
# 31629    0
# 37283    0
# 37335    1
# 44764    0
# 44835    0
# 48391    0
# 48965    1
# 52230    0
# 56197    0
# 58696    0
# 59949    1
# 60834    0
# 60878    0
# 63067    0
# 65130    1
# 67083    1
# 67463    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 2 (15705 data points).
# cholesterol 3
# Split on feature cholesterol. (14073, 1632)
# --------------------------------------------------------------------
# Subtree, depth = 3 (14073 data points).
# active None
# Split on feature active. (2837, 11236)
# --------------------------------------------------------------------
# Subtree, depth = 4 (2837 data points).
# ap_lo 74
# Split on feature ap_lo. (652, 2185)
# --------------------------------------------------------------------
# Subtree, depth = 5 (652 data points).
# weight 53.0
# Split on feature weight. (45, 607)
# --------------------------------------------------------------------
# Subtree, depth = 6 (45 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 388      0
# 2982     1
# 3858     0
# 4391     0
# 8491     0
# 12083    0
# 12581    0
# 13415    0
# 14098    0
# 15179    0
# 16677    0
# 17868    0
# 23667    0
# 24012    1
# 29680    0
# 30109    0
# 30337    1
# 34518    0
# 35365    0
# 36133    1
# 36740    1
# 38401    0
# 39648    1
# 39919    0
# 39977    0
# 40146    1
# 42318    0
# 43946    0
# 47809    0
# 49142    0
# 50258    0
# 51411    1
# 53224    0
# 53597    0
# 55625    0
# 57877    0
# 58937    0
# 62085    0
# 63113    1
# 63557    0
# 63760    0
# 65170    0
# 65445    0
# 65799    1
# 68109    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (607 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 69       1
# 277      1
# 722      0
# 889      0
# 922      0
#         ..
# 69180    1
# 69202    1
# 69295    1
# 69437    1
# 69579    0
# Name: cardio, Length: 607, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (2185 data points).
# weight 84.0
# Split on feature weight. (1793, 392)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1793 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 5        0
# 55       0
# 104      1
# 110      1
# 126      0
#         ..
# 69824    1
# 69840    0
# 69902    0
# 69964    1
# 69969    0
# Name: cardio, Length: 1793, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (392 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 57       1
# 98       1
# 515      1
# 585      1
# 669      0
#         ..
# 68597    0
# 69216    0
# 69567    0
# 69686    1
# 69947    1
# Name: cardio, Length: 392, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (11236 data points).
# ap_lo 80
# Split on feature ap_lo. (2938, 8298)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2938 data points).
# weight 62.0
# Split on feature weight. (795, 2143)
# --------------------------------------------------------------------
# Subtree, depth = 6 (795 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 19       0
# 23       0
# 72       0
# 95       0
# 266      0
#         ..
# 69585    0
# 69635    1
# 69827    0
# 69865    0
# 69988    0
# Name: cardio, Length: 795, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (2143 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 43       1
# 148      0
# 151      1
# 164      0
# 188      0
#         ..
# 69707    0
# 69766    1
# 69823    0
# 69916    0
# 69989    1
# Name: cardio, Length: 2143, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (8298 data points).
# weight 92.0
# Split on feature weight. (7725, 573)
# --------------------------------------------------------------------
# Subtree, depth = 6 (7725 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 10       0
# 35       0
# 63       0
# 64       1
# 70       1
#         ..
# 69931    1
# 69933    1
# 69945    0
# 69976    0
# 69999    0
# Name: cardio, Length: 7725, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (573 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 76       1
# 160      0
# 173      0
# 286      0
# 306      1
#         ..
# 69641    1
# 69704    1
# 69862    1
# 69914    0
# 69975    1
# Name: cardio, Length: 573, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 3 (1632 data points).
# weight 69.0
# Split on feature weight. (602, 1030)
# --------------------------------------------------------------------
# Subtree, depth = 4 (602 data points).
# gluc 3
# Split on feature gluc. (247, 355)
# --------------------------------------------------------------------
# Subtree, depth = 5 (247 data points).
# gender 2
# Split on feature gender. (180, 67)
# --------------------------------------------------------------------
# Subtree, depth = 6 (180 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 599      1
# 1556     0
# 1831     0
# 1959     1
# 2172     1
#         ..
# 68432    1
# 68681    1
# 68728    1
# 69337    1
# 69731    1
# Name: cardio, Length: 180, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (67 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 2523     0
# 3030     1
# 5156     1
# 5336     0
# 8926     0
#         ..
# 66945    1
# 67160    1
# 67202    1
# 68756    1
# 69697    1
# Name: cardio, Length: 67, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (355 data points).
# height 162
# Split on feature height. (155, 200)
# --------------------------------------------------------------------
# Subtree, depth = 6 (155 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 207      1
# 265      1
# 399      1
# 741      1
# 1056     0
#         ..
# 66775    0
# 66844    0
# 67604    1
# 67771    0
# 68608    0
# Name: cardio, Length: 155, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (200 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 1190     0
# 1211     1
# 1319     0
# 2106     1
# 2478     1
#         ..
# 68478    1
# 68632    0
# 68813    0
# 69147    1
# 69396    1
# Name: cardio, Length: 200, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (1030 data points).
# height 186
# Split on feature height. (1024, 6)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1024 data points).
# gluc 3
# Split on feature gluc. (574, 450)
# --------------------------------------------------------------------
# Subtree, depth = 6 (574 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 253      1
# 416      1
# 462      1
# 815      1
# 927      1
#         ..
# 69402    1
# 69477    1
# 69746    1
# 69863    1
# 69939    1
# Name: cardio, Length: 574, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (450 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 111      1
# 354      1
# 367      1
# 410      1
# 419      1
#         ..
# 69142    1
# 69317    1
# 69446    1
# 69682    1
# 69956    0
# Name: cardio, Length: 450, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (6 data points).
# Stopping condition 1 reached. All data points have the same target value.
# 31729    0
# 31904    0
# 33327    0
# 51003    0
# 62176    0
# 69047    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 1 (28674 data points).
# ap_lo 90
# Split on feature ap_lo. (9864, 18810)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9864 data points).
# cholesterol 3
# Split on feature cholesterol. (8014, 1850)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8014 data points).
# age 61
# Split on feature age. (6466, 1548)
# --------------------------------------------------------------------
# Subtree, depth = 4 (6466 data points).
# height 176
# Split on feature height. (5921, 545)
# --------------------------------------------------------------------
# Subtree, depth = 5 (5921 data points).
# weight 58.0
# Split on feature weight. (404, 5517)
# --------------------------------------------------------------------
# Subtree, depth = 6 (404 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 108      1
# 141      1
# 187      1
# 293      1
# 360      0
#         ..
# 68880    0
# 69430    1
# 69494    1
# 69535    0
# 69689    1
# Name: cardio, Length: 404, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (5517 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 16       0
# 21       0
# 29       0
# 33       1
# 66       0
#         ..
# 69959    1
# 69966    0
# 69973    0
# 69985    1
# 69994    1
# Name: cardio, Length: 5517, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (545 data points).
# weight 72.0
# Split on feature weight. (63, 482)
# --------------------------------------------------------------------
# Subtree, depth = 6 (63 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 971      0
# 1003     0
# 1114     0
# 2908     1
# 3854     1
#         ..
# 63871    0
# 65518    0
# 66852    0
# 69389    0
# 69578    0
# Name: cardio, Length: 63, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (482 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 94       0
# 237      1
# 242      1
# 435      0
# 728      1
#         ..
# 69294    1
# 69378    1
# 69426    0
# 69873    1
# 69971    0
# Name: cardio, Length: 482, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (1548 data points).
# weight 149.0
# Split on feature weight. (1545, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1545 data points).
# alco None
# Split on feature alco. (1482, 63)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1482 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 22       1
# 38       1
# 132      0
# 137      0
# 170      1
#         ..
# 69855    1
# 69857    1
# 69868    1
# 69897    1
# 69998    1
# Name: cardio, Length: 1482, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (63 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 297      0
# 407      1
# 913      0
# 2924     1
# 3125     1
#         ..
# 67560    1
# 68403    0
# 68718    0
# 68844    0
# 69850    0
# Name: cardio, Length: 63, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Stopping condition 1 reached. All data points have the same target value.
# 2458     0
# 30633    0
# 63687    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 3 (1850 data points).
# gluc 3
# Split on feature gluc. (1130, 720)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1130 data points).
# height 154
# Split on feature height. (132, 998)
# --------------------------------------------------------------------
# Subtree, depth = 5 (132 data points).
# age 63
# Split on feature age. (108, 24)
# --------------------------------------------------------------------
# Subtree, depth = 6 (108 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 125      0
# 2780     1
# 2942     1
# 3074     0
# 4344     1
#         ..
# 67953    1
# 68483    1
# 68573    0
# 68896    1
# 69120    1
# Name: cardio, Length: 108, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (24 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 966      0
# 1499     0
# 2956     1
# 4910     0
# 8945     1
# 14003    1
# 14570    1
# 18959    0
# 29544    1
# 30003    1
# 32807    0
# 33868    1
# 35625    1
# 35811    0
# 37316    0
# 39683    1
# 46433    0
# 54442    1
# 57045    0
# 57486    1
# 58072    0
# 60465    0
# 62443    1
# 67538    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (998 data points).
# smoke None
# Split on feature smoke. (899, 99)
# --------------------------------------------------------------------
# Subtree, depth = 6 (899 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 2        1
# 6        0
# 44       1
# 194      1
# 299      1
#         ..
# 69606    1
# 69749    0
# 69871    1
# 69940    1
# 69949    1
# Name: cardio, Length: 899, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (99 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 182      1
# 1618     1
# 2177     1
# 3505     1
# 3739     1
#         ..
# 68542    1
# 68931    0
# 69201    0
# 69491    0
# 69970    1
# Name: cardio, Length: 99, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (720 data points).
# height 171
# Split on feature height. (583, 137)
# --------------------------------------------------------------------
# Subtree, depth = 5 (583 data points).
# age 63
# Split on feature age. (486, 97)
# --------------------------------------------------------------------
# Subtree, depth = 6 (486 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 166      1
# 489      1
# 616      0
# 635      0
# 875      1
#         ..
# 69199    1
# 69394    1
# 69461    0
# 69564    1
# 69624    1
# Name: cardio, Length: 486, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (97 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 351      1
# 850      1
# 1774     1
# 3297     1
# 4385     1
#         ..
# 64026    1
# 64371    1
# 64998    1
# 69177    1
# 69907    1
# Name: cardio, Length: 97, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (137 data points).
# weight 98.0
# Split on feature weight. (105, 32)
# --------------------------------------------------------------------
# Subtree, depth = 6 (105 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 303      1
# 936      1
# 972      1
# 1162     1
# 1474     1
#         ..
# 68407    0
# 69304    0
# 69630    0
# 69792    1
# 69869    1
# Name: cardio, Length: 105, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (32 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 3212     1
# 4956     1
# 5668     1
# 7659     0
# 12070    1
# 18544    1
# 19059    1
# 21821    1
# 22501    0
# 23383    1
# 28014    1
# 28205    1
# 31615    1
# 34165    1
# 36522    1
# 36642    1
# 38442    1
# 38974    1
# 39743    1
# 40969    1
# 42970    1
# 49197    1
# 50179    1
# 50720    0
# 52466    1
# 52820    1
# 53525    0
# 57461    1
# 58865    1
# 60045    1
# 61942    0
# 69728    1
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 2 (18810 data points).
# cholesterol 2
# Split on feature cholesterol. (11661, 7149)
# --------------------------------------------------------------------
# Subtree, depth = 3 (11661 data points).
# gluc 3
# Split on feature gluc. (11336, 325)
# --------------------------------------------------------------------
# Subtree, depth = 4 (11336 data points).
# weight 53.67
# Split on feature weight. (247, 11089)
# --------------------------------------------------------------------
# Subtree, depth = 5 (247 data points).
# height 158
# Split on feature height. (150, 97)
# --------------------------------------------------------------------
# Subtree, depth = 6 (150 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 859      1
# 1164     1
# 1521     1
# 1563     1
# 1816     1
#         ..
# 67864    1
# 67868    1
# 68092    1
# 69666    1
# 69734    1
# Name: cardio, Length: 150, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (97 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 248      0
# 824      1
# 1525     0
# 1789     1
# 1889     0
#         ..
# 65875    0
# 68670    1
# 68816    1
# 69058    1
# 69293    0
# Name: cardio, Length: 97, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (11089 data points).
# alco None
# Split on feature alco. (10446, 643)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10446 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 3        1
# 26       0
# 37       0
# 39       1
# 42       1
#         ..
# 69967    1
# 69972    1
# 69982    1
# 69992    1
# 69993    1
# Name: cardio, Length: 10446, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (643 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 14       0
# 62       0
# 146      0
# 476      1
# 537      1
#         ..
# 69482    1
# 69593    1
# 69708    1
# 69780    1
# 69915    1
# Name: cardio, Length: 643, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (325 data points).
# gender 2
# Split on feature gender. (196, 129)
# --------------------------------------------------------------------
# Subtree, depth = 5 (196 data points).
# weight 109.0
# Split on feature weight. (182, 14)
# --------------------------------------------------------------------
# Subtree, depth = 6 (182 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 333      1
# 712      1
# 1485     1
# 1646     1
# 2150     1
#         ..
# 69171    1
# 69347    0
# 69422    1
# 69577    1
# 69819    1
# Name: cardio, Length: 182, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (14 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 22583    1
# 23466    1
# 23705    1
# 24682    0
# 35030    1
# 40165    0
# 43495    0
# 43661    1
# 45654    1
# 48859    0
# 51909    1
# 61006    0
# 67043    0
# 67887    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (129 data points).
# weight 93.0
# Split on feature weight. (87, 42)
# --------------------------------------------------------------------
# Subtree, depth = 6 (87 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 1829     1
# 1970     0
# 5050     1
# 5200     1
# 5966     1
#         ..
# 64587    1
# 64703    1
# 65908    1
# 68437    0
# 68487    0
# Name: cardio, Length: 87, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (42 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 446      1
# 1935     0
# 2967     0
# 3528     0
# 4724     1
# 8671     0
# 9582     0
# 11090    0
# 11886    0
# 12108    0
# 12193    1
# 14546    0
# 14555    0
# 15539    0
# 16198    1
# 16384    0
# 23002    1
# 23351    1
# 31297    1
# 31588    1
# 32182    0
# 33204    0
# 33310    0
# 33626    1
# 36689    1
# 36794    0
# 38241    0
# 39804    0
# 40018    1
# 40409    0
# 42340    1
# 44157    0
# 47288    0
# 48870    1
# 54952    1
# 59358    0
# 62451    1
# 66288    1
# 66621    0
# 67231    0
# 69115    0
# 69745    1
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 3 (7149 data points).
# gluc 2
# Split on feature gluc. (4456, 2693)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4456 data points).
# age 58
# Split on feature age. (2763, 1693)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2763 data points).
# weight 75.0
# Split on feature weight. (1063, 1700)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1063 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 24       1
# 25       0
# 192      1
# 221      1
# 244      1
#         ..
# 69556    1
# 69623    0
# 69657    0
# 69692    1
# 69911    1
# Name: cardio, Length: 1063, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (1700 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 1        1
# 46       1
# 61       1
# 101      0
# 105      1
#         ..
# 69492    1
# 69668    1
# 69837    0
# 69918    1
# 69997    1
# Name: cardio, Length: 1700, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (1693 data points).
# weight 102.0
# Split on feature weight. (1588, 105)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1588 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 31       1
# 34       1
# 67       1
# 147      1
# 156      1
#         ..
# 69830    1
# 69888    1
# 69925    1
# 69943    1
# 69944    1
# Name: cardio, Length: 1588, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (105 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 212      1
# 543      1
# 1515     1
# 2251     1
# 2411     1
#         ..
# 67866    1
# 68264    1
# 68480    1
# 68948    1
# 69440    1
# Name: cardio, Length: 105, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 4 (2693 data points).
# weight 50.0
# Split on feature weight. (16, 2677)
# --------------------------------------------------------------------
# Subtree, depth = 5 (16 data points).
# Early stopping condition 2 reached. Reached minimum node size.
# 7941     0
# 12365    0
# 12920    1
# 16906    1
# 17522    1
# 22307    0
# 22476    1
# 38184    0
# 38242    0
# 43759    0
# 47123    0
# 47646    1
# 52017    1
# 57858    1
# 59212    1
# 59303    0
# Name: cardio, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 5 (2677 data points).
# age 59
# Split on feature age. (1751, 926)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1751 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 53       1
# 74       0
# 87       1
# 91       1
# 268      0
#         ..
# 69846    1
# 69920    1
# 69929    1
# 69981    1
# 69991    0
# Name: cardio, Length: 1751, dtype: int64
# --------------------------------------------------------------------
# Subtree, depth = 6 (926 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# 7        1
# 86       1
# 329      1
# 384      1
# 469      1
#         ..
# 69651    1
# 69699    1
# 69938    0
# 69979    1
# 69996    1
# Name: cardio, Length: 926, dtype: int64

# %%
custom_decision_tree_c.get_feature_importances()
# Out:
# [('ap_hi', 0.7519950784021698),
#  ('age', 0.10106882206393643),
#  ('cholesterol', 0.06879832834023578),
#  ('ap_lo', 0.03755062634572772),
#  ('weight', 0.0182598832823869),
#  ('gluc', 0.008977403627978863),
#  ('active', 0.00785441770523592),
#  ('height', 0.00392604338930343),
#  ('gender', 0.0009098838177823137),
#  ('alco', 0.0004574095279035313),
#  ('smoke', 0.0002021034973394077)]

# %%
accuracy(cardio_df[target], custom_decision_tree_c.predict(cardio_df[features]))
# Out:
# 0.7299714285714286
